# %%
import pandas as pd
import numpy as np

# %%
Trans=pd.read_csv(r"C:\Users\gaura\Downloads\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey CSV\transaction_data.csv")
Trans
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0                 2375  26984851472    1     1004906         1         1.39
# 1                 2375  26984851472    1     1033142         1         0.82
# 2                 2375  26984851472    1     1036325         1         0.99
# 3                 2375  26984851472    1     1082185         1         1.21
# 4                 2375  26984851472    1     8160430         1         1.50
# ...                ...          ...  ...         ...       ...          ...
# 2595727           1598  42305362535  711       92130         1         0.99
# 2595728           1598  42305362535  711      114102         1         8.89
# 2595729           1598  42305362535  711      133449         1         6.99
# 2595730           1598  42305362535  711     6923644         1         4.50
# 2595731           1598  42305362535  711    14055192         1         6.99
#
# ...

# %%
Trans.size
# Out:
# 31148784

# %%
Trans.shape
# Out:
# (2595732, 12)

# %%
Trans.dtypes
# Out:
# household_key          int64
# BASKET_ID              int64
# DAY                    int64
# PRODUCT_ID             int64
# QUANTITY               int64
# SALES_VALUE          float64
# STORE_ID               int64
# RETAIL_DISC          float64
# TRANS_TIME             int64
# WEEK_NO                int64
# COUPON_DISC          float64
# COUPON_MATCH_DISC    float64
# dtype: object

# %%
Trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2595732 entries, 0 to 2595731
# Data columns (total 12 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   household_key      int64
#  1   BASKET_ID          int64
#  2   DAY                int64
#  3   PRODUCT_ID         int64
#  4   QUANTITY           int64
#  5   SALES_VALUE        float64
#  6   STORE_ID           int64
#  7   RETAIL_DISC        float64
#  8   TRANS_TIME         int64
#  9   WEEK_NO            int64
#  10  COUPON_DISC        float64
#  11  COUPON_MATCH_DISC  float64
# dtypes: float64(4), int64(8)
# memory usage: 237.6 MB

# %%
Trans.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0       364        -0.60        1631        1          0.0                0.0
# 1       364         0.00        1631        1          0.0                0.0
# 2       364        -0.30        1631        1          0.0                0.0
# 3       364         0.00        1631        1          0.0                0.0
# 4       364        -0.39        1631        1          0.0                0.0

# %%
Trans.tail()
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 2595727           1598  42305362535  711       92130         1         0.99
# 2595728           1598  42305362535  711      114102         1         8.89
# 2595729           1598  42305362535  711      133449         1         6.99
# 2595730           1598  42305362535  711     6923644         1         4.50
# 2595731           1598  42305362535  711    14055192         1         6.99
#
#          STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  \
# 2595727      3228         0.00        1520      102          0.0
# 2595728      3228         0.00        1520      102          0.0
# 2595729      3228         0.00        1520      102          0.0
# 2595730      3228        -0.49        1520      102          0.0
# 2595731      3228         0.00        1520      102          0.0
#
#          COUPON_MATCH_DISC
# 2595727                0.0
# 2595728                0.0
# 2595729                0.0
# ...

# %%
Trans.isnull().sum()
# Out:
# household_key        0
# BASKET_ID            0
# DAY                  0
# PRODUCT_ID           0
# QUANTITY             0
# SALES_VALUE          0
# STORE_ID             0
# RETAIL_DISC          0
# TRANS_TIME           0
# WEEK_NO              0
# COUPON_DISC          0
# COUPON_MATCH_DISC    0
# dtype: int64

# %%
Trans.duplicated().sum()
# Out:
# np.int64(0)

# %%
Trans.describe()
# Out:
#        household_key     BASKET_ID           DAY    PRODUCT_ID      QUANTITY  \
# count   2.595732e+06  2.595732e+06  2.595732e+06  2.595732e+06  2.595732e+06
# mean    1.271953e+03  3.402620e+10  3.887562e+02  2.891435e+06  1.004286e+02
# std     7.260660e+02  4.711649e+09  1.897210e+02  3.837404e+06  1.153436e+03
# min     1.000000e+00  2.698485e+10  1.000000e+00  2.567100e+04  0.000000e+00
# 25%     6.560000e+02  3.040805e+10  2.290000e+02  9.174590e+05  1.000000e+00
# 50%     1.272000e+03  3.276081e+10  3.900000e+02  1.028816e+06  1.000000e+00
# 75%     1.913000e+03  4.012685e+10  5.530000e+02  1.133018e+06  1.000000e+00
# max     2.500000e+03  4.230536e+10  7.110000e+02  1.831630e+07  8.963800e+04
#
#         SALES_VALUE      STORE_ID   RETAIL_DISC    TRANS_TIME       WEEK_NO  \
# count  2.595732e+06  2.595732e+06  2.595732e+06  2.595732e+06  2.595732e+06
# mean   3.104120e+00  3.142673e+03 -5.387054e-01  1.561586e+03  5.622150e+01
# ...

# %%
Trans.nunique()
# Out:
# household_key          2500
# BASKET_ID            276484
# DAY                     711
# PRODUCT_ID            92339
# QUANTITY              11746
# SALES_VALUE            5502
# STORE_ID                582
# RETAIL_DISC            2414
# TRANS_TIME             1440
# WEEK_NO                 102
# COUPON_DISC             415
# COUPON_MATCH_DISC        80
# dtype: int64

# %%
(Trans["SALES_VALUE"] < 0).sum()
# Out:
# np.int64(0)

# %%
(Trans["RETAIL_DISC"] < 0).sum()
# Out:
# np.int64(1303026)

# %%
Trans["QUANTITY"].describe()
# Out:
# count    2.595732e+06
# mean     1.004286e+02
# std      1.153436e+03
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      8.963800e+04
# Name: QUANTITY, dtype: float64

# %%
(Trans["SALES_VALUE"] == 0).sum()
# Out:
# np.int64(18850)

# %%
Trans.memory_usage(deep=True).sum()/1024**2
# Out:
# np.float64(237.64648818969727)

# %%
Trans[Trans["SALES_VALUE"] == 0].head(20)
# Out:
#       household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 97              744  26985165432    1     5978648         0          0.0
# 128            1287  26985336468    1     5978648         0          0.0
# 249            2305  26996870743    2     5978656         0          0.0
# 293             271  26997082949    2     5978656         0          0.0
# 694             315  27008952267    3      957951         0          0.0
# 766            2110  27009082349    3      837963         1          0.0
# 996             568  27021090189    4      951412         1          0.0
# 1089             14  27021203242    4     6463658         0          0.0
# 1095           2110  27021248054    4      850115         1          0.0
# 1113           2110  27021248054    4      976872         1          0.0
# 1161            474  27021262361    4      940108         1          0.0
# 1649           2305  27031060487    5     5978648         0          0.0
# ...

# %%
Trans[Trans["SALES_VALUE"] == 0][["SALES_VALUE","RETAIL_DISC","COUPON_DISC","COUPON_MATCH_DISC"]].describe()
# Out:
#        SALES_VALUE   RETAIL_DISC   COUPON_DISC  COUPON_MATCH_DISC
# count      18850.0  18850.000000  18850.000000       18850.000000
# mean           0.0     -0.781153     -0.550489          -0.000289
# std            0.0      1.816268      1.505729           0.011747
# min            0.0    -39.950000    -37.930000          -0.500000
# 25%            0.0      0.000000     -0.500000           0.000000
# 50%            0.0      0.000000      0.000000           0.000000
# 75%            0.0      0.000000      0.000000           0.000000
# max            0.0      0.010000      0.000000           0.000000

# %% [markdown]
# Data Cleaning Decision:
# Identified 18,850 transactions with SALES_VALUE = 0. After examining associated retail and coupon discounts, these transactions appear to represent promotional or fully discounted purchases rather than data errors. Therefore, these records were retained for analysis.

# %%
Trans.sort_values("QUANTITY", ascending=False).head(20)
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 1750942            630  34749153595  503     6534178     89638       250.00
# 468356            2407  29392047893  181     6544236     85055       210.00
# 481876             630  29484790880  185     6534178     61335       150.21
# 166536             149  28210551971  103     6534178     51912       110.00
# 1340882            193  32956767959  402     6534178     48073       121.10
# 2472791           2133  41904760458  682     6534178     45475       100.00
# 1560340            149  33768630428  456     6534178     41833       115.00
# 376686             149  29035716247  158     6534178     41686       100.00
# 156049            1406  28167562655   99     6544236     41485        85.00
# 87625              107  27865225627   74     6534178     39365        72.00
# 752631             630  30822908062  256     6534178     38348        71.67
# ...

# %%
Trans["QUANTITY"].value_counts().head(20)
# Out:
# QUANTITY
# 1     2050967
# 2      372373
# 3       66962
# 4       38667
# 0       14466
# 5       10918
# 6        8981
# 8        2531
# 10       2219
# 7        1379
# 12        909
# 9         863
# 11        208
# 20        186
# 15        178
# 14        136
# 16        122
# 13        107
# 24         97
# 18         52
# Name: count, dtype: int64

# %%
(Trans["QUANTITY"] == 0).sum()
# Out:
# np.int64(14466)

# %%
pdt=pd.read_csv(r"C:\Users\gaura\Downloads\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey CSV\product.csv")
pdt
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# ...

# %%
pdt.columns
# Out:
# Index(['PRODUCT_ID', 'MANUFACTURER', 'DEPARTMENT', 'BRAND', 'COMMODITY_DESC',
#        'SUB_COMMODITY_DESC', 'CURR_SIZE_OF_PRODUCT'],
#       dtype='object')

# %%
pdt[pdt["PRODUCT_ID"].isin([6534178, 6544236, 6534166])]
# Out:
#        PRODUCT_ID  MANUFACTURER       DEPARTMENT    BRAND     COMMODITY_DESC  \
# 57216     6534166            69  MISC SALES TRAN  Private  COUPON/MISC ITEMS
# 57221     6534178            69        KIOSK-GAS  Private  COUPON/MISC ITEMS
# 57335     6544236            69  MISC SALES TRAN  Private  COUPON/MISC ITEMS
#
#           SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 57216  GASOLINE-REG UNLEADED
# 57221  GASOLINE-REG UNLEADED
# 57335  GASOLINE-REG UNLEADED

# %%
pdt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92353 entries, 0 to 92352
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PRODUCT_ID            92353 non-null  int64
#  1   MANUFACTURER          92353 non-null  int64
#  2   DEPARTMENT            92353 non-null  object
#  3   BRAND                 92353 non-null  object
#  4   COMMODITY_DESC        92353 non-null  object
#  5   SUB_COMMODITY_DESC    92353 non-null  object
#  6   CURR_SIZE_OF_PRODUCT  92353 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 4.9+ MB

# %%
pdt.isnull().sum()
# Out:
# PRODUCT_ID              0
# MANUFACTURER            0
# DEPARTMENT              0
# BRAND                   0
# COMMODITY_DESC          0
# SUB_COMMODITY_DESC      0
# CURR_SIZE_OF_PRODUCT    0
# dtype: int64

# %%
pdt.duplicated().sum()
# Out:
# np.int64(0)

# %%
pdt["PRODUCT_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
pdt.nunique()
# Out:
# PRODUCT_ID              92353
# MANUFACTURER             6476
# DEPARTMENT                 44
# BRAND                       2
# COMMODITY_DESC            308
# SUB_COMMODITY_DESC       2383
# CURR_SIZE_OF_PRODUCT     4345
# dtype: int64

# %%
pdt.describe(include="all")
# Out:
#           PRODUCT_ID  MANUFACTURER DEPARTMENT     BRAND  \
# count   9.235300e+04   92353.00000      92353     92353
# unique           NaN           NaN         44         2
# top              NaN           NaN    GROCERY  National
# freq             NaN           NaN      39021     78537
# mean    5.328353e+06    1739.22833        NaN       NaN
# std     5.359937e+06    1818.26957        NaN       NaN
# min     2.567100e+04       1.00000        NaN       NaN
# 25%     9.706280e+05     328.00000        NaN       NaN
# 50%     1.621091e+06    1094.00000        NaN       NaN
# 75%     9.704770e+06    2264.00000        NaN       NaN
# max     1.831630e+07    6477.00000        NaN       NaN
#
#                         COMMODITY_DESC SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# count                            92353              92353                92353
# unique                             308               2383                 4345
# ...

# %%
pdt.head()
# Out:
#    PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND            COMMODITY_DESC  \
# 0       25671             2       GROCERY  National                  FRZN ICE
# 1       26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
# 2       26093            69        PASTRY   Private                     BREAD
# 3       26190            69       GROCERY   Private      FRUIT - SHELF STABLE
# 4       26355            69       GROCERY   Private             COOKIES/CONES
#
#             SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION
# 2         BREAD:ITALIAN/FRENCH
# 3                  APPLE SAUCE                50 OZ
# 4            SPECIALTY COOKIES                14 OZ

# %%
pdt.tail()
# Out:
#        PRODUCT_ID  MANUFACTURER DEPARTMENT     BRAND COMMODITY_DESC  \
# 92348    18293142          6384    DRUG GM  National      BOOKSTORE
# 92349    18293439          6393    DRUG GM  National      BOOKSTORE
# 92350    18293696          6406    DRUG GM  National      BOOKSTORE
# 92351    18294080          6442    DRUG GM  National      BOOKSTORE
# 92352    18316298           764    GROCERY  National   PAPER TOWELS
#
#            SUB_COMMODITY_DESC CURR_SIZE_OF_PRODUCT
# 92348         PAPERBACK BOOKS
# 92349       CHILDRENS LOW END
# 92350   PAPERBACK BEST SELLER
# 92351         PAPERBACK BOOKS
# 92352  PAPER TOWELS & HOLDERS

# %%
pdt.shape
# Out:
# (92353, 7)

# %%
pdt.size
# Out:
# 646471

# %%
pdt.dtypes
# Out:
# PRODUCT_ID               int64
# MANUFACTURER             int64
# DEPARTMENT              object
# BRAND                   object
# COMMODITY_DESC          object
# SUB_COMMODITY_DESC      object
# CURR_SIZE_OF_PRODUCT    object
# dtype: object

# %%
coupon=pd.read_csv(r"C:\Users\gaura\Downloads\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey CSV\coupon.csv")
coupon
# Out:
#          COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0       10000089061       27160         4
# 1       10000089064       27754         9
# 2       10000089073       28897        12
# 3       51800009050       28919        28
# 4       52100000076       28929        25
# ...             ...         ...       ...
# 124543  10000085478    13038802        18
# 124544  10000085479    13039368        18
# 124545  10000085478    13039553        18
# 124546  10000085479    13776332        18
# 124547  10000085477    13213390        18
#
# [124548 rows x 3 columns]

# %%
coupon.shape
# Out:
# (124548, 3)

# %%
coupon.size
# Out:
# 373644

# %%
coupon.head()
# Out:
#     COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0  10000089061       27160         4
# 1  10000089064       27754         9
# 2  10000089073       28897        12
# 3  51800009050       28919        28
# 4  52100000076       28929        25

# %%
coupon.tail()
# Out:
#          COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 124543  10000085478    13038802        18
# 124544  10000085479    13039368        18
# 124545  10000085478    13039553        18
# 124546  10000085479    13776332        18
# 124547  10000085477    13213390        18

# %%
coupon["COUPON_UPC"].duplicated().sum()
# Out:
# np.int64(123413)

# %%
coupon["PRODUCT_ID"].duplicated().sum()
# Out:
# np.int64(80415)

# %%
coupon[coupon.duplicated(keep=False)].sort_values(
    ["COUPON_UPC","PRODUCT_ID","CAMPAIGN"])
# Out:
#         COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 73199  10000085426      930799        13
# 73748  10000085426      930799        13
# 62387  10000085427      983002        13
# 64785  10000085427      983002        13
# 64507  10000085427     1078612        13
# ...            ...         ...       ...
# 47353  58304613024     8019845        30
# 47354  58304613024     8019845        30
# 47355  58304613024     8019845        30
# 47356  58304613024     8019845        30
# 47357  58304613024     8019845        30
#
# [6988 rows x 3 columns]

# %%
coupon.groupby(
    ["COUPON_UPC","PRODUCT_ID","CAMPAIGN"]
).size().sort_values(ascending=False).head(20)
# Out:
# COUPON_UPC   PRODUCT_ID  CAMPAIGN
# 57940011080  921912      27          19
# 57940011075  921912      27          19
# 57940018081  6704447     27          17
# 57940018076  6704447     27          17
# 54589314175  1024433     27          16
# 54589314187  1024433     27          16
# 57940018081  7167488     27          16
# 57940018076  7167488     27          16
# 51111131075  1065098     27          15
# 54100027032  1118641     27          15
# 51111122275  5565415     27          15
# 51111131082  1065098     27          15
# 57940041075  933409      27          15
# 57940041055  933409      27          15
# 51111122081  5565415     27          15
# 51111122275  942300      27          14
# 54589314175  940099      27          14
# 54589314187  940099      27          14
# 51111122081  942300      27          14
#              1079365     27          14
# dtype: int64

# %%
coupon.columns
# Out:
# Index(['COUPON_UPC', 'PRODUCT_ID', 'CAMPAIGN'], dtype='object')

# %%
coupon.describe
# Out:
# <bound method NDFrame.describe of          COUPON_UPC  PRODUCT_ID  CAMPAIGN
# 0       10000089061       27160         4
# 1       10000089064       27754         9
# 2       10000089073       28897        12
# 3       51800009050       28919        28
# 4       52100000076       28929        25
# ...             ...         ...       ...
# 124543  10000085478    13038802        18
# 124544  10000085479    13039368        18
# 124545  10000085478    13039553        18
# 124546  10000085479    13776332        18
# 124547  10000085477    13213390        18
#
# [124548 rows x 3 columns]>

# %%
coupon.isnull().sum()
# Out:
# COUPON_UPC    0
# PRODUCT_ID    0
# CAMPAIGN      0
# dtype: int64

# %%
coupon.duplicated().sum()
# Out:
# np.int64(5164)

# %%
coupon.drop_duplicates().shape
# Out:
# (119384, 3)

# %%
coupon = coupon.drop_duplicates()

# %% [markdown]
# Coupon Table Cleaning
#
# Missing values: 0
# Exact duplicate rows: 5,164
# Action: Removed duplicate records after confirming that all column values were identical.
# Reason: Duplicate records can inflate coupon counts and lead to incorrect campaign analysis.

# %%
cp=pd.read_csv(r"C:\Users\gaura\Downloads\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey CSV\coupon_redempt.csv")
cp
# Out:
#       household_key  DAY   COUPON_UPC  CAMPAIGN
# 0                 1  421  10000085364         8
# 1                 1  421  51700010076         8
# 2                 1  427  54200000033         8
# 3                 1  597  10000085476        18
# 4                 1  597  54200029176        18
# ...             ...  ...          ...       ...
# 2313           2496  592  54900050076        18
# 2314           2496  610  55100000013        18
# 2315           2500  449  53663200076         8
# 2316           2500  449  54300031076         8
# 2317           2500  624  55000013950        18
#
# [2318 rows x 4 columns]

# %%
cp.shape
# Out:
# (2318, 4)

# %%
cp.size
# Out:
# 9272

# %%
cp.duplicated().sum()
# Out:
# np.int64(0)

# %%
cp.isnull().sum()
# Out:
# household_key    0
# DAY              0
# COUPON_UPC       0
# CAMPAIGN         0
# dtype: int64

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2318 entries, 0 to 2317
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   household_key  2318 non-null   int64
#  1   DAY            2318 non-null   int64
#  2   COUPON_UPC     2318 non-null   int64
#  3   CAMPAIGN       2318 non-null   int64
# dtypes: int64(4)
# memory usage: 72.6 KB

# %%
cp.nunique()
# Out:
# household_key    434
# DAY              328
# COUPON_UPC       556
# CAMPAIGN          30
# dtype: int64

# %%
cp.describe(include="all")
# Out:
#        household_key          DAY    COUPON_UPC     CAMPAIGN
# count    2318.000000  2318.000000  2.318000e+03  2318.000000
# mean     1302.816652   528.217429  4.123049e+10    15.551337
# std       783.002545   100.360985  1.986068e+10     5.716636
# min         1.000000   225.000000  1.000009e+10     1.000000
# 25%       588.000000   458.250000  1.000009e+10    13.000000
# 50%      1396.500000   532.000000  5.234003e+10    14.000000
# 75%      2004.000000   605.000000  5.430002e+10    18.000000
# max      2500.000000   704.000000  5.897850e+10    30.000000

# %%
hh=pd.read_csv(r"C:\Users\gaura\Downloads\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey CSV\hh_demographic.csv")
hh
# Out:
#     classification_1 classification_2 classification_3 HOMEOWNER_DESC  \
# 0         Age Group6                X           Level4      Homeowner
# 1         Age Group4                X           Level5      Homeowner
# 2         Age Group2                Y           Level3        Unknown
# 3         Age Group2                Y           Level6      Homeowner
# 4         Age Group4                Z           Level5      Homeowner
# ..               ...              ...              ...            ...
# 796       Age Group3                Y           Level5      Homeowner
# 797       Age Group4                X           Level6      Homeowner
# 798       Age Group4                Y           Level4        Unknown
# 799       Age Group2                Y           Level5      Homeowner
# 800       Age Group2                Y           Level1        Unknown
#
#     classification_5 classification_4 KID_CATEGORY_DESC  household_key
# ...

# %%
hh.shape
# Out:
# (801, 8)

# %%
hh.size
# Out:
# 6408

# %%
hh.isnull().sum()
# Out:
# classification_1     0
# classification_2     0
# classification_3     0
# HOMEOWNER_DESC       0
# classification_5     0
# classification_4     0
# KID_CATEGORY_DESC    0
# household_key        0
# dtype: int64

# %%
hh.duplicated().sum()
# Out:
# np.int64(0)

# %%
hh["household_key"].duplicated().sum()
# Out:
# np.int64(0)

# %%
hh.describe(include="all")
# Out:
#        classification_1 classification_2 classification_3 HOMEOWNER_DESC  \
# count               801              801              801            801
# unique                6                3               12              5
# top          Age Group4                Y           Level5      Homeowner
# freq                288              344              192            504
# mean                NaN              NaN              NaN            NaN
# std                 NaN              NaN              NaN            NaN
# min                 NaN              NaN              NaN            NaN
# 25%                 NaN              NaN              NaN            NaN
# 50%                 NaN              NaN              NaN            NaN
# 75%                 NaN              NaN              NaN            NaN
# max                 NaN              NaN              NaN            NaN
#
#        classification_5 classification_4 KID_CATEGORY_DESC  household_key
# ...

# %%
hh.nunique()
# Out:
# classification_1       6
# classification_2       3
# classification_3      12
# HOMEOWNER_DESC         5
# classification_5       6
# classification_4       5
# KID_CATEGORY_DESC      4
# household_key        801
# dtype: int64

# %%
hh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   classification_1   801 non-null    object
#  1   classification_2   801 non-null    object
#  2   classification_3   801 non-null    object
#  3   HOMEOWNER_DESC     801 non-null    object
#  4   classification_5   801 non-null    object
#  5   classification_4   801 non-null    object
#  6   KID_CATEGORY_DESC  801 non-null    object
#  7   household_key      801 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 50.2+ KB

# %%
cd=pd.read_csv(r"C:\Users\gaura\Downloads\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey CSV\causal_data.csv")
cd
# Out:
#           PRODUCT_ID  STORE_ID  WEEK_NO display mailer
# 0              26190       286       70       0      A
# 1              26190       288       70       0      A
# 2              26190       289       70       0      A
# 3              26190       292       70       0      A
# 4              26190       293       70       0      A
# ...              ...       ...      ...     ...    ...
# 36786519    18203921       439      100       1      0
# 36786520    18203921       439      101       1      0
# 36786521    18243471       415      101       3      0
# 36786522    18243476       415      101       3      0
# 36786523    18244453       345      101       7      0
#
# [36786524 rows x 5 columns]

# %%
cd.shape
# Out:
# (36786524, 5)

# %%
cd.size
# Out:
# 183932620

# %%
cd.head()
# Out:
#    PRODUCT_ID  STORE_ID  WEEK_NO display mailer
# 0       26190       286       70       0      A
# 1       26190       288       70       0      A
# 2       26190       289       70       0      A
# 3       26190       292       70       0      A
# 4       26190       293       70       0      A

# %%
cd.tail()
# Out:
#           PRODUCT_ID  STORE_ID  WEEK_NO display mailer
# 36786519    18203921       439      100       1      0
# 36786520    18203921       439      101       1      0
# 36786521    18243471       415      101       3      0
# 36786522    18243476       415      101       3      0
# 36786523    18244453       345      101       7      0

# %%
cd.isnull().sum()
# Out:
# PRODUCT_ID    0
# STORE_ID      0
# WEEK_NO       0
# display       0
# mailer        0
# dtype: int64

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36786524 entries, 0 to 36786523
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   PRODUCT_ID  int64
#  1   STORE_ID    int64
#  2   WEEK_NO     int64
#  3   display     object
#  4   mailer      object
# dtypes: int64(3), object(2)
# memory usage: 1.4+ GB

# %%
cd.duplicated().sum()
# Out:
# np.int64(0)

# %%
cd.nunique()
# Out:
# PRODUCT_ID    68377
# STORE_ID        115
# WEEK_NO          93
# display          10
# mailer           11
# dtype: int64

# %%
cam=pd.read_csv(r"C:\Users\gaura\Downloads\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey CSV\campaign_desc.csv")
cam
# Out:
#    DESCRIPTION  CAMPAIGN  START_DAY  END_DAY
# 0        TypeB        24        659      719
# 1        TypeC        15        547      708
# 2        TypeB        25        659      691
# 3        TypeC        20        615      685
# 4        TypeB        23        646      684
# 5        TypeB        21        624      656
# 6        TypeB        22        624      656
# 7        TypeA        18        587      642
# 8        TypeB        19        603      635
# 9        TypeB        17        575      607
# 10       TypeC        14        531      596
# 11       TypeB        16        561      593
# 12       TypeA        13        504      551
# 13       TypeB        11        477      523
# 14       TypeB        12        477      509
# 15       TypeB        10        463      495
# 16       TypeB         9        435      467
# 17       TypeA         8        412      460
# 18       TypeB         7        398      432
# 19       TypeC         6        393      425
# ...

# %%
cam.shape
# Out:
# (30, 4)

# %%
cam.size
# Out:
# 120

# %%
cam.head()
# Out:
#   DESCRIPTION  CAMPAIGN  START_DAY  END_DAY
# 0       TypeB        24        659      719
# 1       TypeC        15        547      708
# 2       TypeB        25        659      691
# 3       TypeC        20        615      685
# 4       TypeB        23        646      684

# %%
cam.tail()
# Out:
#    DESCRIPTION  CAMPAIGN  START_DAY  END_DAY
# 25       TypeA        30        323      369
# 26       TypeB        29        281      334
# 27       TypeB        28        259      320
# 28       TypeC        27        237      300
# 29       TypeA        26        224      264

# %%
cam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DESCRIPTION  30 non-null     object
#  1   CAMPAIGN     30 non-null     int64
#  2   START_DAY    30 non-null     int64
#  3   END_DAY      30 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.1+ KB

# %%
cam.isnull().sum()
# Out:
# DESCRIPTION    0
# CAMPAIGN       0
# START_DAY      0
# END_DAY        0
# dtype: int64

# %%
cam.duplicated().sum()
# Out:
# np.int64(0)

# %%
cam.nunique()
# Out:
# DESCRIPTION     3
# CAMPAIGN       30
# START_DAY      27
# END_DAY        28
# dtype: int64

# %%
ct=pd.read_csv(r"C:\Users\gaura\Downloads\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey\dunnhumby_The-Complete-Journey CSV\campaign_table.csv")
ct
# Out:
#      DESCRIPTION  household_key  CAMPAIGN
# 0          TypeA             17        26
# 1          TypeA             27        26
# 2          TypeA            212        26
# 3          TypeA            208        26
# 4          TypeA            192        26
# ...          ...            ...       ...
# 7203       TypeC           1803        15
# 7204       TypeC           1082        15
# 7205       TypeC            942        15
# 7206       TypeC            855        15
# 7207       TypeC            334        15
#
# [7208 rows x 3 columns]

# %%
ct.shape
# Out:
# (7208, 3)

# %%
ct.size
# Out:
# 21624

# %%
ct.head()
# Out:
#   DESCRIPTION  household_key  CAMPAIGN
# 0       TypeA             17        26
# 1       TypeA             27        26
# 2       TypeA            212        26
# 3       TypeA            208        26
# 4       TypeA            192        26

# %%
ct.tail()
# Out:
#      DESCRIPTION  household_key  CAMPAIGN
# 7203       TypeC           1803        15
# 7204       TypeC           1082        15
# 7205       TypeC            942        15
# 7206       TypeC            855        15
# 7207       TypeC            334        15

# %%
ct.isnull().sum()
# Out:
# DESCRIPTION      0
# household_key    0
# CAMPAIGN         0
# dtype: int64

# %%
ct.duplicated().sum()
# Out:
# np.int64(0)

# %%
ct.nunique()
# Out:
# DESCRIPTION         3
# household_key    1584
# CAMPAIGN           30
# dtype: int64

# %%
ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7208 entries, 0 to 7207
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DESCRIPTION    7208 non-null   object
#  1   household_key  7208 non-null   int64
#  2   CAMPAIGN       7208 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 169.1+ KB

# %%
# Folder path
save_path = r"C:\Gaurav Personal\DA & DS"

# Save all cleaned tables
Trans.to_csv(f"{save_path}\clean_transaction_data.csv", index=False)

pdt.to_csv(f"{save_path}\clean_product.csv", index=False)

coupon.to_csv(f"{save_path}\clean_coupon.csv", index=False)

cp.to_csv(f"{save_path}\clean_coupon_redempt.csv", index=False)

hh.to_csv(f"{save_path}\clean_hh_demographic.csv", index=False)

cd.to_csv(f"{save_path}\clean_causal_data.csv", index=False)

cam.to_csv(f"{save_path}\clean_campaign_desc.csv", index=False)

ct.to_csv(f"{save_path}\clean_campaign_table.csv", index=False)

print("All 8 cleaned CSV files have been saved successfully!")
# Out:
# ✅ All 8 cleaned CSV files have been saved successfully!
